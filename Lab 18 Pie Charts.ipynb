# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 208.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 213.5 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 144.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 151.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 109.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 164.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-07-02 01:33:24--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  68.4MB/s    in 2.2s
#
# 2025-07-02 01:33:26 (68.4 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("survey-data.csv")

# Select relevant column and drop missing values
df_db = df['DatabaseWantToWorkWith'].dropna()

# Split semicolon-separated values into lists
df_db = df_db.str.split(';')

# Explode to have one database per row
df_exploded = df_db.explode()

# Clean whitespace
df_exploded = df_exploded.str.strip()

# Count frequency of each database
db_counts = df_exploded.value_counts()

# Select top 5
top5 = db_counts.head(5)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    top5,
    labels=top5.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("survey-data.csv")

# Select and drop missing DevType entries
df_dev = df['DevType'].dropna()

# Split semicolon-separated strings into lists
df_dev = df_dev.str.split(';')

# Explode into one role per row
df_exploded = df_dev.explode()

# Clean whitespace
df_exploded = df_exploded.str.strip()

# Count occurrences of each developer role
dev_counts = df_exploded.value_counts()

# Select top 5 roles
top5_roles = dev_counts.head(5)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    top5_roles,
    labels=top5_roles.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top 5 Developer Roles')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
df.columns.to_list()
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'Check',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'TechDoc',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'BuildvsBuy',
#  'TechEndorse',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'EmbeddedHaveWorkedWith',
#  'EmbeddedWantToWorkWith',
#  'EmbeddedAdmired',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'MiscTechAdmired',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'ToolsTechAdmired',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
# ...

# %%
df['OpSysProfessional use'].head(20)
# Out:
# 0                                                  NaN
# 1                                                MacOS
# 2                                              Windows
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                MacOS
# 7                                                MacOS
# 8                                                MacOS
# 9                                              Windows
# 10                                             Windows
# 11           Windows;Windows Subsystem for Linux (WSL)
# 12                   Windows Subsystem for Linux (WSL)
# 13    Ubuntu;Windows;Windows Subsystem for Linux (WSL)
# 14                                     Red Hat;Windows
# 15                                             Windows
# 16                                                 NaN
# ...

# %%
df_prof = df['OpSysProfessional use'].dropna()
df_prof = df_prof.str.split(";")
df_prof_explode = df_prof.explode()
df_prof_explode = df_prof_explode.str.strip()

# Count occurrences of each developer role
df_prof_explode_counts = df_prof_explode.value_counts()
df_prof_top5 = df_prof_explode_counts.head(5)
plt.pie(
    df_prof_top5,
    labels=df_prof_top5.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top Operating System')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
df['LanguageHaveWorkedWith'].head(10)
# Out:
# 0                                                  NaN
# 1    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                   C#
# 3    C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4              C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 5    Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                    R
# 7                       HTML/CSS;JavaScript;TypeScript
# 8                                                  Lua
# 9                       HTML/CSS;JavaScript;TypeScript
# Name: LanguageHaveWorkedWith, dtype: object

# %%
##Write your code here
df_lang = df['LanguageHaveWorkedWith'].dropna()
df_lang = df_lang.str.split(";")
df_lang_explode = df_lang.explode()
df_lang_explode = df_lang_explode.str.strip()

# Count occurrences of each developer role
df_lang_explode_counts = df_lang_explode.value_counts()
df_lang_top10 = df_lang_explode_counts.head(10)
plt.pie(
    df_lang_top10,
    labels=df_lang_top10.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top Languages The Applicant Have worked with')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
df_collab = df["NEWCollabToolsHaveWorkedWith"].dropna()
df_collab = df_collab.str.split(";")
df_collab_expl = df_collab.explode()
df_collab_count = df_collab_expl.value_counts()
df_collab_top10 = df_collab_count.head(10)
plt.pie(
    df_collab_top10,
    labels=df_collab_top10.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Set3.colors
)
plt.title('Top 10 Collab The Applicant Have worked with')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
df["LanguageAdmired"].head(10)
# Out:
# 0                                                  NaN
# 1    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                   C#
# 3    HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                   C++;HTML/CSS;JavaScript;Lua;Python
# 5    Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                    R
# 7                       HTML/CSS;JavaScript;TypeScript
# 8                                                  Lua
# 9                       HTML/CSS;JavaScript;TypeScript
# Name: LanguageAdmired, dtype: object

# %%
##Write your code here
df_admire = df["LanguageAdmired"].dropna()
df_admire = df_admire.str.split(";")
df_admire_explode = df_admire.explode()
df_admire_explode = df_admire_explode.str.strip()

# Count occurrences of each developer role
df_admire_explode_counts = df_admire_explode.value_counts()
df_admire_top10 = df_admire_explode_counts.head(10)
plt.pie(
    df_admire_top10,
    labels=df_admire_top10.index,
    autopct='%1.1f%%',
    
    startangle=140,
    colors=plt.cm.Set2_r.colors
)
plt.title('Top Languages The Resipondents Admire')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %%
dir(plt.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Grays_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
# ...

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
df["AIToolCurrently Using"].head(10)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Learning about a codebase;Project planning;Wri...
# 4                                                  NaN
# 5              Writing code;Debugging and getting help
# 6                                                  NaN
# 7    Writing code;Debugging and getting help;Search...
# 8                                                  NaN
# 9                                   Search for answers
# Name: AIToolCurrently Using, dtype: object

# %%
##Write your code here
df_ai = df["AIToolCurrently Using"].dropna()
df_ai = df_ai.str.split(";")
df_ai_explode = df_ai.explode()
df_ai_explode = df_ai_explode.str.strip()

# Count occurrences of each developer role
df_ai_explode_counts = df_ai_explode.value_counts()
df_ai_top7 = df_ai_explode_counts.head(7)
plt.pie(
    df_ai_top7,
    labels=df_ai_top7.index,
    autopct='%1.1f%%',
    
    startangle=140,
    colors=plt.cm.Set2_r.colors
)
plt.title('Top Languages The Resipondents Admire', y=1.05)
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
df["WebframeWantToWorkWith"].head(10)
# Out:
# 0                                 NaN
# 1    Express;Htmx;Node.js;React;Remix
# 2                        ASP.NET CORE
# 3        jQuery;Next.js;Node.js;React
# 4                                 NaN
# 5                             Node.js
# 6                                 NaN
# 7                       Next.js;React
# 8                                 NaN
# 9       Express;Next.js;Node.js;React
# Name: WebframeWantToWorkWith, dtype: object

# %%
##Write your code here
df_web = df["WebframeWantToWorkWith"].dropna()
df_web = df_web.str.split(";")
df_web_explode = df_web.explode()
df_web_explode = df_web_explode.str.strip()

# Count occurrences of each developer role
df_web_explode_counts = df_web_explode.value_counts()
df_web_top7 = df_web_explode_counts.head(7)
plt.pie(
    df_web_top7,
    labels=df_web_top7.index,
    autopct='%1.1f%%',
    
    startangle=140,
    colors=plt.cm.Set2_r.colors
)
plt.title('Top Web Frames Respondents Have Worked With', y=1.05)
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
df["EmbeddedWantToWorkWith"].head(10)
# Out:
# 0                  NaN
# 1                  NaN
# 2          Rasberry Pi
# 3                  NaN
# 4    CMake;Rasberry Pi
# 5          Rasberry Pi
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# Name: EmbeddedWantToWorkWith, dtype: object

# %%
##Write your code here
##Write your code here
df_embed = df["EmbeddedWantToWorkWith"].dropna()
df_embed = df_embed.str.split(";")
df_embed_explode = df_embed.explode()
df_embed_explode = df_embed_explode.str.strip()

# Count occurrences of each developer role
df_embed_explode_counts = df_embed_explode.value_counts()
df_embed_top5 = df_embed_explode_counts.head(5)
plt.pie(
    df_embed_top5,
    labels=df_embed_top5.index,
    autopct='%1.1f%%',
    
    startangle=140,
    colors=plt.cm.Set2_r.colors
)
plt.title('Top Embedded  Respondents Want to Work With', y=1.05)
plt.axis('equal')  # Equal aspect ratio ensures pie is circular.
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
